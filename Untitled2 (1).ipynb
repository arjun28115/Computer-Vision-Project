# %%
import cv2
import os

img_path = os.path.join("images", "sample1.jpg")
img_bgr = cv2.imread(img_path)

if img_bgr is None:
    raise FileNotFoundError("Image not found. Check the path.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1983555566.py in <cell line: 0>()
#       6
#       7 if img_bgr is None:
# ----> 8     raise FileNotFoundError("Image not found. Check the path.")
#
# FileNotFoundError: Image not found. Check the path.

# %%
import cv2
import matplotlib.pyplot as plt

# Convert color spaces
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)

# Display images side by side
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.title("RGB")
plt.imshow(img_rgb)
plt.axis("off")

plt.subplot(1,3,2)
plt.title("Grayscale")
plt.imshow(img_gray, cmap='gray')
plt.axis("off")

plt.subplot(1,3,3)
plt.title("HSV")
plt.imshow(img_hsv)
plt.axis("off")

plt.show()
